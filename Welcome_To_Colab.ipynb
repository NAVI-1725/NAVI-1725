# %% [markdown]
# <a href="https://colab.research.google.com/github/NAVI-1725/NAVI-1725/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit

# %%
from qiskit.quantum_info import Statevector
from qiskit import QuantumCircuit

# %%
u = Statevector([1,0])

# %%
circuit = QuantumCircuit(1)

circuit.x(0)
circuit.h(0)
circuit.z(0)

display(circuit.draw())
# Out:
#    ┌───┐┌───┐┌───┐
# q: ┤ X ├┤ H ├┤ Z ├
#    └───┘└───┘└───┘

# %%
result = u.evolve(circuit)
print(result)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
from qiskit.visualization import plot_bloch_multivector, plot_state_qsphere
import matplotlib.pyplot as plt

# %%
bloch_plot = plot_bloch_multivector(result)
display(bloch_plot)

# %%
qsphere = plot_state_qsphere(result)
display(qsphere)
